# %%
# Out:
# C:\Users\u300737\AppData\Local\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# Typhon module cannot be loaded

# %%
# Out:
# 2022-03-15 10:19:22     6.376948
# 2022-03-15 10:28:33    15.368212
# 2022-03-15 10:34:37    17.392624
# 2022-03-15 10:41:45    16.324043
# 2022-03-15 10:49:06    14.542633
# 2022-03-15 10:55:47    10.135697
# 2022-03-15 11:03:29     6.254908
# 2022-03-15 11:52:30    16.995649
# 2022-03-15 12:05:05    13.995756
# 2022-03-15 12:28:34    14.185241
# 2022-03-15 12:36:29    16.549746
# 2022-03-15 12:40:08    16.919144
# 2022-03-15 12:43:47    16.604868
# 2022-03-15 14:00:48    16.456410
# 2022-03-15 14:11:44     5.671213
# 2022-03-15 14:34:01     7.035898
# 2022-03-15 14:40:56    12.076714
# 2022-03-15 14:47:58    15.894112
# 2022-03-15 14:54:30    15.039071
# 2022-03-15 15:01:07    13.702338
# 2022-03-15 15:05:56    10.606679
# 2022-03-15 15:13:18     7.711693
# 2022-03-15 16:09:45    15.740010
# 2022-03-15 16:22:53     6.968169
# 2022-03-15 16:44:06     6.191610
# dtype: float64

# %%
# Out:
# Radar reflectivty dBZg corrected for gaseous attenuation
# Radar reflectivity Zg corrected for gaseous attenuation

# %%
#radar_ds
# Out:
# <xarray.Dataset>
# Dimensions:          (time: 31310, height: 434)
# Coordinates:
#   * time             (time) datetime64[ns] 2022-03-15T09:04:50 ... 2022-03-15...
#   * height           (height) float64 0.0 30.0 60.0 ... 1.296e+04 1.299e+04
# Data variables: (12/14)
#     dBZg             (time, height) float64 nan nan nan nan ... nan nan nan nan
#     Zg               (time, height) float64 nan nan nan nan ... nan nan nan nan
#     LDRg             (time, height) float64 ...
#     RMSg             (time, height) float64 ...
#     VELg             (time, height) float64 ...
#     SNRg             (time, height) float64 ...
#     ...               ...
#     lon              (time) float64 ...
#     alt              (time) float64 ...
#     radar_flag       (time, height) float64 ...
#     Gas_Attenuation  (time, height) float64 nan nan nan nan ... nan nan nan nan
#     dBZg_old         (time, height) float64 ...
#     Zg_old           (time, height) float64 ...
# ...

# %%
#processed_radar = radar_ds.copy()  # Run the combined plot
# Out:
# 0        11917.846661
# 1        11917.846661
# 2        11917.846661
# 3        11917.846661
# 4        11917.846661
#              ...
# 31305    11917.846661
# 31306    11917.846661
# 31307    11917.846661
# 31308    11917.846661
# 31309    11917.846661
# Length: 31310, dtype: float64
# <urlopen error [Errno 11001] getaddrinfo failed>
# <urlopen error [Errno 11001] getaddrinfo failed>
# <urlopen error [Errno 11001] getaddrinfo failed>
# <urlopen error [Errno 11001] getaddrinfo failed>
# <urlopen error [Errno 11001] getaddrinfo failed>
# <urlopen error [Errno 11001] getaddrinfo failed>
# <urlopen error [Errno 11001] getaddrinfo failed>
# <urlopen error [Errno 11001] getaddrinfo failed>
# <urlopen error [Errno 11001] getaddrinfo failed>
# <urlopen error [Errno 11001] getaddrinfo failed>
# <urlopen error [Errno 11001] getaddrinfo failed>
